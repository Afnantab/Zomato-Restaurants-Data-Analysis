# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato=pd.read_csv("zomatocleaned.csv")
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato.isnull().sum()
# Out:
# Unnamed: 0          0
# name                0
# online_order        0
# book_table          0
# rating              0
# votes               0
# location            0
# rest_type         107
# dish_liked      13213
# cuisines            6
# approx_cost         0
# type             2584
# dtype: int64

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30336 entries, 0 to 30335
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    30336 non-null  int64
#  1   name          30336 non-null  object
#  2   online_order  30336 non-null  object
#  3   book_table    30336 non-null  object
#  4   rating        30336 non-null  float64
#  5   votes         30336 non-null  int64
#  6   location      30336 non-null  object
#  7   rest_type     30229 non-null  object
#  8   dish_liked    17123 non-null  object
#  9   cuisines      30330 non-null  object
#  10  approx_cost   30336 non-null  object
#  11  type          27752 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.8+ MB

# %%
zomato.head()
# Out:
#    Unnamed: 0                   name online_order book_table  rating  votes  \
# 0           0                  Jalsa          Yes        Yes     4.1    775
# 1           1         Spice Elephant          Yes         No     4.1    787
# 2           2        San Churro Cafe          Yes         No     3.8    918
# 3           3  Addhuri Udupi Bhojana           No         No     3.7     88
# 4           4          Grand Village           No         No     3.8    166
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# ...

# %%
zomato["rest_type"].fillna("casual Dining",inplace=True)

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato.isnull().sum()
# Out:
# Unnamed: 0          0
# name                0
# online_order        0
# book_table          0
# rating              0
# votes               0
# location            0
# rest_type           0
# dish_liked      13213
# cuisines            6
# approx_cost         0
# type             2584
# dtype: int64

# %%
zomato.head()
# Out:
#    Unnamed: 0                   name online_order book_table  rating  votes  \
# 0           0                  Jalsa          Yes        Yes     4.1    775
# 1           1         Spice Elephant          Yes         No     4.1    787
# 2           2        San Churro Cafe          Yes         No     3.8    918
# 3           3  Addhuri Udupi Bhojana           No         No     3.7     88
# 4           4          Grand Village           No         No     3.8    166
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# ...

# %%
zomato.value_counts(["dish_liked"])
# Out:
# dish_liked
# Biryani                                                                                            135
# Chicken Biryani                                                                                     51
# Paratha                                                                                             47
# Friendly Staff                                                                                      46
# Waffles                                                                                             44
#                                                                                                   ...
# Poha, Samosa, Ginger Chai, Ginger Tea, Banana Cake, Cake Rusk, Coffee                                1
# Dal Makhani, Galauti Kebab, Dum Biryani, Rasgulla, Fish, Garlic Kheer, Tandoori Broccoli             1
# Dal Makhani, Kulcha, Butter Chicken, Makke Ki Roti, Garlic Naan, Tandoori Chicken, Palak Paneer      1
# ...

# %%
zomato["dish_liked"].fillna("Biryani",inplace=True)

# %%
zomato.isnull().sum()
# Out:
# Unnamed: 0         0
# name               0
# online_order       0
# book_table         0
# rating             0
# votes              0
# location           0
# rest_type          0
# dish_liked         0
# cuisines           6
# approx_cost        0
# type            2584
# dtype: int64

# %%
zomato.head()
# Out:
#    Unnamed: 0                   name online_order book_table  rating  votes  \
# 0           0                  Jalsa          Yes        Yes     4.1    775
# 1           1         Spice Elephant          Yes         No     4.1    787
# 2           2        San Churro Cafe          Yes         No     3.8    918
# 3           3  Addhuri Udupi Bhojana           No         No     3.7     88
# 4           4          Grand Village           No         No     3.8    166
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# ...

# %%
zomato.value_counts(["cuisines"])
# Out:
# cuisines
# North Indian                                      1595
# North Indian, Chinese                             1412
# South Indian                                       902
# Bakery, Desserts                                   473
# Biryani                                            434
#                                                   ...
# Continental, Italian, Mediterranean, Salad           1
# Salad, Fast Food, Sandwich, Healthy Food             1
# Asian, Thai, Vietnamese, Malaysian, Beverages        1
# Salad, Beverages, Juices                             1
# North Indian, South Indian, Asian, Continental       1
# Name: count, Length: 2495, dtype: int64

# %%
zomato["cuisines"].fillna("North Indian",inplace=True)

# %%
zomato.isnull().sum()
# Out:
# Unnamed: 0         0
# name               0
# online_order       0
# book_table         0
# rating             0
# votes              0
# location           0
# rest_type          0
# dish_liked         0
# cuisines           0
# approx_cost        0
# type            2584
# dtype: int64

# %%
zomato.head()
# Out:
#    Unnamed: 0                   name online_order book_table  rating  votes  \
# 0           0                  Jalsa          Yes        Yes     4.1    775
# 1           1         Spice Elephant          Yes         No     4.1    787
# 2           2        San Churro Cafe          Yes         No     3.8    918
# 3           3  Addhuri Udupi Bhojana           No         No     3.7     88
# 4           4          Grand Village           No         No     3.8    166
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# ...

# %%
zomato.value_counts(["type"])
# Out:
# type
# Delivery              13153
# Dine-out              10188
# Desserts               1953
# Cafes                   964
# Drinks & nightlife      572
# Buffet                  513
# Pubs and bars           409
# Name: count, dtype: int64

# %%
zomato["type"].fillna("Delivery",inplace=True)

# %%
zomato.isnull().sum()
# Out:
# Unnamed: 0      0
# name            0
# online_order    0
# book_table      0
# rating          0
# votes           0
# location        0
# rest_type       0
# dish_liked      0
# cuisines        0
# approx_cost     0
# type            0
# dtype: int64

# %%
zomato.duplicated().sum()
# Out:
# 0

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato.rename(columns={"Unnamed:0":"ID"},inplace=True)

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato.reset_index(drop=True,inplace=True)

# %%
zomato
# Out:
#        Unnamed: 0                                               name  \
# 0               0                                              Jalsa
# 1               1                                     Spice Elephant
# 2               2                                    San Churro Cafe
# 3               3                              Addhuri Udupi Bhojana
# 4               4                                      Grand Village
# ...           ...                                                ...
# 30331       56244                         The Farm House Bar n Grill
# 30332       56246                                            Bhagini
# 30333       56247  Best Brews - Four Points by Sheraton Bengaluru...
# 30334       56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 30335       56251                       The Nest - The Den Bengaluru
#
#       online_order book_table  rating  votes                    location  \
# ...

# %%
zomato["votes"].head(10).plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
# Approx cost votes
zomato_1=zomato["votes"].head(10)
plt.bar(zomato["approx_cost"][:10],zomato_1)
plt.show()

# %%
# Top 10 restaurant chains by count
top_chains = zomato['name'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_chains.values, y=top_chains.index, palette="viridis")
plt.title("Top 10 Restaurant Chains in Zomato Dataset")
plt.xlabel("Number of Outlets")
plt.ylabel("Restaurant Name")
plt.show()

# %%
city_avg_rating = zomato.groupby("location")["rating"].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=city_avg_rating.values, y=city_avg_rating.index, palette="magma")
plt.title("Top 10 Cities by Average Restaurant Rating")
plt.xlabel("Average Rating")
plt.ylabel("location")
plt.show()

# %%
# Split cuisines and count most common
from collections import Counter

cuisines = zomato['cuisines'].dropna().str.split(",").sum()
cuisine_counts = pd.Series(cuisines).str.strip().value_counts().head(15)

plt.figure(figsize=(12,6))
sns.barplot(x=cuisine_counts.values, y=cuisine_counts.index, palette="coolwarm")
plt.title("Top 15 Popular Cuisines")
plt.xlabel("Number of Restaurants")
plt.ylabel("Cuisine")
plt.show()

# %%
rating_by_online = zomato.groupby("online_order")["rating"].mean().sort_values(ascending=False)
print(rating_by_online)

plt.figure(figsize=(6,4))
sns.barplot(x=rating_by_online.index, y=rating_by_online.values)
plt.title("Average Rating by Online Ordering")
plt.xlabel("Online Order (Yes/No)")
plt.ylabel("Average Rating")
plt.tight_layout()
plt.show()
# Out:
# online_order
# Yes    3.613684
# No     3.433299
# Name: rating, dtype: float64

# %%
# Top 10 popular cuisines
plt.figure(figsize=(10,6))
zomato['cuisines'].str.split(',').explode().str.strip().value_counts().head(10).plot(kind='bar', color='coral')
plt.title("Top 10 Popular Cuisines", fontsize=14)
plt.xlabel("Cuisine", fontsize=12)
plt.ylabel("Count of Restaurants", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# avrage rating by resturant type
plt.figure(figsize=(10,6))
sns.barplot(x='rest_type', y='rating', data=zomato, errorbar=None, palette="viridis")
plt.title("Average Rating by Restaurant Type", fontsize=14)
plt.xlabel("Restaurant Type", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Online order vs NO online order 
plt.figure(figsize=(6,5))
sns.boxplot(x="online_order", y="votes", data=zomato, palette="Set1")
plt.title("Votes Distribution: Online Order vs No Online Order", fontsize=14)
plt.xlabel("Online Ordering Available", fontsize=12)
plt.ylabel("Votes", fontsize=12)
plt.show()

# %%
# Destribution of resturant rating
plt.figure(figsize=(8,5))
sns.histplot(zomato['rating'], bins=20, kde=True, color="purple")
plt.title("Distribution of Restaurant Ratings", fontsize=14)
plt.xlabel("Ratings", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.show()
# Out:
# E:\Users\Faisal Ahmed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Average rate across price ranges
plt.figure(figsize=(8,5))
sns.barplot(x="online_order", y="rating", data=zomato, palette="coolwarm", errorbar=None)
plt.title("Average Rating Across Price Ranges", fontsize=14)
plt.xlabel("Price Range", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.show()

# %%
# Top 15 cities with most resturants
plt.figure(figsize=(12,6))
zomato['location'].value_counts().head(15).plot(kind='bar', color="teal")
plt.title("Top 15 Cities with Most Restaurants", fontsize=14)
plt.xlabel("City", fontsize=12)
plt.ylabel("Number of Restaurants", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Table booking availbility ratings
plt.figure(figsize=(6,5))
sns.boxplot(x="book_table", y="rating", data=zomato, palette="Set2")
plt.title("Table Booking Availability vs Ratings", fontsize=14)
plt.xlabel("Table Booking", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.show()

# %% [markdown]
# --->>>Project Outcome:
#
# This analysis helped uncover customer preferences, restaurant trends, and engagement factors using Zomato’s dataset.
#
# The findings can be used by:
#
# Business Owners → to identify which cuisines and services (online delivery, table booking) attract more customers.
#
# Customers → to choose restaurants with better service quality.
#
# Investors/Planners → to focus on cities with high restaurant density and cuisines with high demand.
#
# By combining EDA + Visualizations, this project demonstrates how data analytics can provide actionable insights for the food & restaurant industry.
